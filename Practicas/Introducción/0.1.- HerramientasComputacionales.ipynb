# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1>Herramientas y Aplicaciones de la Inteligencia Artificial</h1>
#     <h3>Introducción: Herramientas Computacionales</h3>
#
# </div>

# %% [markdown]
# > Bienvenido al curso de Herramientas y Aplicaciones de Inteligencia Artificial. En esta primera unidad conocerás las herramientas computacionales esenciales para el desarrollo de proyectos en IA, así como la guía de instalación y recomendaciones para sacarles el máximo provecho.

# %% [markdown]
# ---
# ## 🐍 Un poco de historia sobre Python
#
# - Python fue creado a finales de los 80 por **Guido van Rossum** en el Centro para las Matemáticas y la Informática (CWI) en los Países Bajos, como sucesor del lenguaje ABC.
# - El nombre "Python" proviene de la afición de su creador por los humoristas británicos **Monty Python**.
# - Es un software libre, de código abierto, regido por la [Python Software Foundation License](https://es.wikipedia.org/wiki/Python_Software_Foundation_License).
# - Es un **lenguaje interpretado** que prioriza la legibilidad y la simplicidad del código.
#
# <div style="background-color:#f9f9f9; border-left:4px solid #000047; padding:10px;">
# <b>¿Por qué Python?</b><br>
# Python es uno de los lenguajes más populares en ciencia de datos, IA, desarrollo web y automatización. Su sintaxis sencilla y la gran cantidad de librerías lo hacen ideal para aprender y trabajar en proyectos reales.
# </div>
#
# - [Python está conquistando el mundo](https://www.economist.com/graphic-detail/2018/07/26/python-is-becoming-the-worlds-most-popular-coding-language)
# - [Python acerca la programación a nuevas audiencias](https://www.economist.com/science-and-technology/2018/07/19/python-has-brought-computer-programming-to-a-vast-new-audience)
#
# Puedes consultar el [Zen of Python](http://www.thezenofpython.com/) para conocer las buenas prácticas recomendadas.

# %% [markdown]
# ---
# ## 🚀 Herramientas Computacionales Esenciales

# %% [markdown]
# ### <img src="https://www.python.org/static/community_logos/python-logo.png" width="40"/> [Python](https://www.python.org)
#
# El lenguaje base para el curso. Fácil de aprender, potente y versátil. Usado en IA, ciencia de datos, automatización y más.
#
# **Ventajas:**
# - Sintaxis clara y sencilla.
# - Gran comunidad y documentación.
# - Multiplataforma.
# - Extensa colección de librerías.

# %% [markdown]
# ### <img src="https://europe1.discourse-cdn.com/anaconda/original/1X/380b1bd1c8486d70cf7ba24fde66fdfa61814336.png" width="150"/> [Anaconda](https://www.anaconda.com/download)
#
# Distribución que facilita la instalación de Python y cientos de librerías científicas. Incluye herramientas como Jupyter y facilita la gestión de entornos virtuales.
#
# **¿Por qué usar Anaconda?**
# - Instalación sencilla de paquetes.
# - Gestión de entornos para evitar conflictos.
# - Incluye Jupyter Notebook y otras herramientas útiles.

# %% [markdown]
# ### <img src="https://jupyter.org/assets/homepage/main-logo.svg" width="30"/> [Jupyter Notebook](https://jupyter.org/)
#
# Entorno interactivo para escribir y ejecutar código Python, visualizar resultados y documentar el proceso en celdas Markdown.
#
# **Características:**
# - Permite combinar código, texto, ecuaciones y visualizaciones.
# - Ideal para experimentación y documentación.
# - Soporte para múltiples lenguajes.

# %% [markdown]
# ---
# ## 📓 ¿Qué es un Jupyter Notebook?
#
# Un Jupyter Notebook es un documento interactivo que combina código ejecutable, texto enriquecido (Markdown), ecuaciones matemáticas y visualizaciones. Es ideal para prototipar, analizar datos y compartir resultados.
#
# **Tipos de celdas:**
# - **Código:** Ejecuta instrucciones en Python y muestra la salida.
# - **Markdown:** Permite escribir texto, ecuaciones y agregar imágenes.
#
# **Ejemplo de celda de código:**

# %%
# Ejemplo: suma de dos números
a = 5
b = 3
print(f"La suma de {a} + {b} es {a + b}")

# %% [markdown]
# **Ejemplo de ecuación en Markdown:**
#
# $$\hat{y} = \beta_2 x^2 + \beta_1 x + \beta_0$$

# %% [markdown]
# **Ecuaciones de Maxwell:**
#
# $$\nabla \cdot \boldsymbol{D} = \rho, \qquad \nabla \cdot \boldsymbol{B} = 0, \qquad \nabla \times \boldsymbol{E} = - \frac{\partial \boldsymbol{B}}{\partial t}, \qquad \nabla \times \boldsymbol{H} = \boldsymbol{J} + \frac{\partial \boldsymbol{D}}{\partial t}$$

# %% [markdown]
# ---
# ## 🛠️ Herramientas de gestión de versiones

# %% [markdown]
# ### <img src="https://git-scm.com/images/logo@2x.png" width="40"/> [git](https://git-scm.com/)
#
# Git es un sistema de control de versiones distribuido, creado por Linus Torvalds. Permite gestionar los cambios en proyectos de software, facilitando el trabajo colaborativo y el seguimiento de la evolución del código.
#
# **¿Por qué usar git?**
# - Permite trabajar en equipo sin perder cambios.
# - Facilita la colaboración y la integración de aportes.
# - Guarda el historial completo de modificaciones.
#
# Git es independiente de GitHub y puede usarse localmente o en servidores remotos.

# %% [markdown]
# ### <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/91/Octicons-mark-github.svg/240px-Octicons-mark-github.svg.png" width="40"/> [GitHub](https://github.com/)
#
# GitHub es una plataforma de alojamiento de repositorios git, que facilita el trabajo colaborativo y remoto. Permite compartir proyectos, gestionar versiones y colaborar con desarrolladores de todo el mundo.
#
# **Ventajas de GitHub:**
# - Control de versiones en la nube.
# - Colaboración global.
# - Integración con herramientas CI/CD.
#
# Se recomienda crear una cuenta profesional, ya que será útil en tu carrera.

# %% [markdown]
# ### <img src="https://www.gitkraken.com/favicon.ico" width="30"/> [GitKraken](https://www.gitkraken.com/)
#
# GitKraken es una interfaz gráfica para git, que facilita la gestión visual de repositorios, ramas y cambios. Es multiplataforma y gratuita para uso no comercial.
#
# **¿Por qué usar una GUI como GitKraken?**
# - Visualización clara de ramas y commits.
# - Simplifica operaciones complejas.
# - Ideal para quienes prefieren evitar la consola.

# %% [markdown]
# ---
# ## 📡 ¿Cómo seguir el proyecto del curso en GitHub?
#
# Para mantenerte sincronizado con el material y participar activamente:
#
# 1. Ingresa al repositorio oficial: [Herramientas_Aplicaciones_IA_2025](https://github.com/gdesirena/Herramientas_Aplicaciones_IA_2025).
# 2. Haz clic en <b>Fork</b> (esquina superior derecha) para copiar el repositorio a tu cuenta.
# 3. Clona tu repositorio desde GitKraken o usando git en la terminal.
#
# <div style="background-color:#f9f9f9; border-left:4px solid #000047; padding:10px;">
# <b>Tip:</b> Recuerda actualizar tu repositorio local periódicamente para obtener las últimas actualizaciones del curso.
# </div>

# %% [markdown]
# # Ejemplo de comandos básicos de git
# ```python
# git clone https://github.com/tu_usuario/Herramientas_Aplicaciones_IA_2025.git
# git pull # Para actualizar tu repositorio local
# git add archivo.py
# git commit -m "Agrega nueva funcionalidad"
# git push

# %% [markdown]
# ---
# ## 📚 Recursos adicionales
#
# - [Documentación oficial de Python](https://docs.python.org/es/3/)
# - [Tutorial de Jupyter Notebook](https://jupyter-notebook.readthedocs.io/en/stable/notebook.html)
# - [Guía rápida de git](https://rogerdudler.github.io/git-guide/index.es.html)
# - [Markdown Guide](https://www.markdownguide.org/basic-syntax/)
#
# <div style="background-color:#e6f2ff; padding:10px; border-radius:10px;">
# </div>
