# %% [markdown]
# <div style="background-color:#e6f2ff; padding:20px; border-radius:10px;">
# <img style="float:left; margin-right:20px;" src='Figures/alinco.png' width="120"/>
# <h1 style="color:#000047;">Tarea 1: Modificación de la librería de clase</h1>
# <br style="clear:both"/>
# </div>
#
# <div style="border-left:4px solid #000047; padding:10px; margin-top:10px; background:#f5f5f5;">
# <b>Objetivo:</b> Construir la librería de la clase con el objetivo de organizar código funciones y clases útilies durante el proceso del curso.
# </div>

# %% [markdown]
# Tomando en cuenta la libreria creada en clase `HyAIA`, y la función de reporte de calidad de datos `dqr()`, realizar lo siguiente:
#
# Modificar la función `dqr()` para tener lo siguiente:

# %%
import pandas as pd
import numpy as np

# %%
from hyaia import HyAIA as hia

# %%
#Utilice el archivo countries.csv
df_countries = pd.read_csv('countries.csv', sep=';')

# %%
#DataFrame
df_countries
# Out:
#     alpha_2 alpha_3       area           capital continent currency_code  \
# 0        AD     AND      468.0  Andorra la Vella        EU           EUR
# 1        AE     ARE    82880.0         Abu Dhabi        AS           AED
# 2        AF     AFG   647500.0             Kabul        AS           AFN
# 3        AG     ATG      443.0        St. John's       NaN           XCD
# 4        AI     AIA      102.0        The Valley       NaN           XCD
# ..      ...     ...        ...               ...       ...           ...
# 247      ZA     ZAF  1219912.0          Pretoria        AF           ZAR
# 248      ZM     ZMB   752614.0            Lusaka        AF           ZMW
# 249      ZW     ZWE   390580.0            Harare        AF           ZWL
# 250      CS     SCG   102350.0          Belgrade        EU           RSD
# 251      AN     ANT      960.0        Willemstad       NaN           ANG
#
#     currency_name eqivalent_fips_code fips  geoname_id  \
# 0            Euro                 NaN   AN     3041565
# 1          Dirham                 NaN   AE      290557
# 2         Afghani                 NaN   AF     1149361
# 3          Dollar                 NaN   AC     3576396
# 4          Dollar                 NaN   AV     3573511
# ..            ...                 ...  ...         ...
# 247          Rand                 NaN   SF      953987
# 248        Kwacha                 NaN   ZA      895949
# 249        Dollar                 NaN   ZI      878675
# 250         Dinar                 NaN   YI     8505033
# 251       Guilder                 NaN   NT     8505032
#
#                                 languages                   name  \
# 0                                      ca                Andorra
# 1                       ar-AE,fa,en,hi,ur   United Arab Emirates
# 2                       fa-AF,ps,uz-AF,tk            Afghanistan
# 3                                   en-AG    Antigua and Barbuda
# 4                                   en-AI               Anguilla
# ..                                    ...                    ...
# 247  zu,xh,af,nso,en-ZA,tn,st,ts,ss,ve,nr           South Africa
# 248          en-ZM,bem,loz,lun,lue,ny,toi                 Zambia
# 249                        en-ZW,sn,nr,nd               Zimbabwe
# 250                           cu,hu,sq,sr  Serbia and Montenegro
# 251                           nl-AN,en,es   Netherlands Antilles
#
#                neighbours  numeric   phone  population postal_code_format  \
# 0                   ES,FR       20     376       84000              AD###
# 1                   SA,OM      784     971     4975593                NaN
# 2       TM,CN,IR,TJ,PK,UZ        4      93    29121286                NaN
# 3                     NaN       28  +1-268       86754                NaN
# 4                     NaN      660  +1-264       13254                NaN
# ..                    ...      ...     ...         ...                ...
# 247     ZW,SZ,MZ,BW,NA,LS      710      27    49000000               ####
# 248  ZW,TZ,MZ,CD,NA,MW,AO      894     260    13460305              #####
# 249           ZA,MZ,BW,ZM      716     263    13061000                NaN
# 250  AL,HU,MK,RO,HR,BA,BG      891     381    10829175              #####
# 251                    GP      530     599      300000                NaN
#
#     postal_code_regex  tld
# 0    ^(?:AD)*(\d{3})$  .ad
# 1                 NaN  .ae
# 2                 NaN  .af
# 3                 NaN  .ag
# 4                 NaN  .ai
# ..                ...  ...
# 247         ^(\d{4})$  .za
# 248         ^(\d{5})$  .zm
# 249               NaN  .zw
# 250         ^(\d{5})$  .cs
# 251               NaN  .an
#
# [252 rows x 19 columns]

# %%
##Modificación en dqr()

# %% [markdown]
# **1.- Modificar la función dqr() para que en el reporte se agregue una columna que sea booleana boolena para representar si una columna es categórica ('Is_categorical') ('Is_categorical' True-->col categorica, False ---> numérica)**

# %% [markdown]
# #==============Contenido en la libreia hyaia.py
#         #Lista de valores Boleanos
#         #1. Columna Boleana ls_categorical
#
#         ls_categorical = pd.DataFrame(columns=['ls_categorical'])
#         for col in list(self.data.columns.values):
#           try:
#               ls_categorical.loc[col] = [self.data[col].dtype =='object' or self.data[col].dtype.name == 'category']
#           except:
#               ls_categorical.loc[col] = [False]

# %% [markdown]
# **2.- Modificar la función dqr() para que en el reporte se agregue una columna con las categorías de las columnas (valores unicos) que resulten ser categóricas (si las categorias > 10, no agregar esas categorias)**

# %% [markdown]
# #==============Contenido en la libreia hyaia.py
#         #Valores Únicos < 10
#         #2. Columna de Categorias de Valores Únicos < 10
#
#         categorias_values = pd.DataFrame(columns=['Categoricas'])
#         for col in list(self.data.columns.values):
#             es_categorical = ls_categorical.loc[col][0] == True
#             if es_categorical:
#                 uniques = self.data[col].dropna().unique()
#                 if len(uniques) <= 10:
#                     categorias_values.loc[col] = [list(uniques)]
#                 else:
#                     categorias_values.loc[col] = [None]
#             else:
#                 categorias_values.loc[col] = [None]

# %% [markdown]
# **3.- Aplicar el análisis estadístico de las columnas creadas (max, min, mean, std) solo para las columnas que sean numéricas ('Is_categorical' == False)**

# %% [markdown]
# #==============Contenido en la libreia hyaia.py se actualizo min y max, y agrego mean y std
#     #3. Análisis estadístico (max, min, mean, std) para columnas númericas Is_categorical == False
#
#         #Lista de valores máximos
#         max_values = pd.DataFrame(columns=['Max_values'])
#
#         for col in self.data.columns.values:
#             if ls_categorical.loc[col][0] == False:
#                 try:
#                     max_values.loc[col] = [self.data[col].max()]
#                 except:
#                     max_values.loc[col] = ['NA']
#             else:
#                 max_values.loc[col] = ['NA']
#
#         #Lista de valores mínimos
#         min_values = pd.DataFrame(columns=['Min_values'])
#
#         for col in self.data.columns:
#             if ls_categorical.loc[col][0] == False:
#                 try:
#                     min_values.loc[col] = [self.data[col].min()]
#                 except:
#                     min_values.loc[col] = ['NA']
#             else:
#                 min_values.loc[col] = ['NA']
#
#         #Lista de Valores con media
#         mean_values = pd.DataFrame(columns=['Mean_values'])
#
#         for col in self.data.columns.values:
#             if ls_categorical.loc[col][0] == False:
#                 try:
#                     mean_values.loc[col] = [self.data[col].mean()]
#                 except:
#                     mean_values.loc[col] = ['NA']
#             else:
#                 mean_values.loc[col] = ['NA']
#
#         #Lista de valores con desviación estandar
#         dstd_values = pd.DataFrame(columns=['Dstd_values'])
#
#         for col in self.data.columns:
#             if ls_categorical.loc[col][0] == False:
#               try:
#                   dstd_values.loc[col] = [self.data[col].std()]
#               except:
#                   dstd_values.loc[col] = ['NA']
#             else:
#                 dstd_values.loc[col] = ['NA']

# %%
df_cat_countries = hia(df_countries)
# Out:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   es_categorical = ls_categorical.loc[col][0] == True
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:
# C:\Users\gabri\Ejercicios_MaestriaIA\3. A_Herramientas\MGRC_Herramientas_Aplicaciones_IA_2025\Modulo1\hyaia.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if ls_categorical.loc[col][0] == False:

# %% [markdown]
# ##Alerta a corregir .....

# %%
df_cat_countries.df_dqr #se registran las tres acciones
# Out:
#                            Columns_Names   Dtypes  Present_values  \
# alpha_2                          alpha_2   object             251
# alpha_3                          alpha_3   object             252
# area                                area  float64             252
# capital                          capital   object             246
# continent                      continent   object             210
# currency_code              currency_code   object             251
# currency_name              currency_name   object             251
# eqivalent_fips_code  eqivalent_fips_code   object               1
# fips                                fips   object             249
# geoname_id                    geoname_id    int64             252
# languages                      languages   object             249
# name                                name   object             252
# neighbours                    neighbours   object             165
# numeric                          numeric    int64             252
# phone                              phone   object             247
# population                    population    int64             252
# postal_code_format    postal_code_format   object             154
# postal_code_regex      postal_code_regex   object             152
# tld                                  tld   object             250
#
#                      Missing_values  Unique_values  ls_categorical  \
# alpha_2                           1            251            True
# alpha_3                           0            252            True
# area                              0            248           False
# capital                           6            244            True
# continent                        42              6            True
# currency_code                     1            155            True
# currency_name                     1             82            True
# eqivalent_fips_code             251              1            True
# fips                              3            249            True
# geoname_id                        0            252           False
# languages                         3            246            True
# name                              0            252            True
# neighbours                       87            159            True
# numeric                           0            252           False
# phone                             5            233            True
# population                        0            249           False
# postal_code_format               98             45            True
# postal_code_regex               100             54            True
# tld                               2            248            True
#
#                                   Categoricas  Max_values Min_values  \
# alpha_2                                  None          NA         NA
# alpha_3                                  None          NA         NA
# area                                     None  17100000.0        0.0
# capital                                  None          NA         NA
# continent            [EU, AS, AF, AN, SA, OC]          NA         NA
# currency_code                            None          NA         NA
# currency_name                            None          NA         NA
# eqivalent_fips_code                      [FI]          NA         NA
# fips                                     None          NA         NA
# geoname_id                               None     8505033      49518
# languages                                None          NA         NA
# name                                     None          NA         NA
# neighbours                               None          NA         NA
# numeric                                  None         894          0
# phone                                    None          NA         NA
# population                               None  1330044000          0
# postal_code_format                       None          NA         NA
# postal_code_regex                        None          NA         NA
# tld                                      None          NA         NA
#
#                          Mean_values       Dstd_values
# alpha_2                           NA                NA
# alpha_3                           NA                NA
# area                   595287.855913    1904817.772759
# capital                           NA                NA
# continent                         NA                NA
# currency_code                     NA                NA
# currency_name                     NA                NA
# eqivalent_fips_code               NA                NA
# fips                              NA                NA
# geoname_id            2427869.984127     1632092.92473
# languages                         NA                NA
# name                              NA                NA
# neighbours                        NA                NA
# numeric                   434.309524        254.663139
# phone                             NA                NA
# population           27276790.083333  116412698.519382
# postal_code_format                NA                NA
# postal_code_regex                 NA                NA
# tld                               NA                NA

# %% [raw]
# Presenta cuatro columnas no categoricas: area, geoname_id, numeric y population, a las que se aplica categoricas y el análisis estadístio
